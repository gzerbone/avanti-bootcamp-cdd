# %% [markdown]
# Criar dicionário de dados, uma estrutura que servirá para explicar o dado que será trabalhado. Você poderá criar um dicionário python contendo as seguintes informações para cada uma das variáveis do conjunto de dados:
#
# `variavel`: nome da coluna no pandas
# `descricao`: descrição da coluna
# `tipo`: quantitativa ou qualitativa
# `subtipo`: nominal, ordinal, discreta, contínua

# %%
import pandas as pd


df_titanic = pd.read_csv('titanic.csv')
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dicionario = {
    "Variavel":["PassengerId","Survived","Pclass","Name","Sex","Age","SibSp","Parch","Ticket","Fare","Cabin","Embarked"],
    "Descricao":["Identificação do passageiro","Verificação se o passageiro sobreviveu(1) ou não(0)","Tipo da passagem: 1°,2° ou 3° Classe","Nome do passageiro","Gênero do passageiro","Idade do passageiro","Quantidade de irmãos ou parceiros abordo no navio","Quantidade de pais ou filhos abordo no navio","Número da passagem","Tarifa por passageiro","Número da cabine","Porto de Embarcação:C = Cherbourg, Q = Queenstown, S = Southampton"],
    "Tipo":["quantitativo","qualitativo","qualitativo","qualitativo","qualitativo","quantitativo","quantitativo","quantitativo","qualitativo","quantitativa","qualitativo","qualitativo"],
    "Subtipo":["discreto","nominal","ordinal","nominal","nominal","contínuo","discreto","discreto","nominal","discreto","nominal","nominal"]
}

dicionario_df = pd.DataFrame(dicionario)
dicionario_df
# Out:
#        Variavel                                          Descricao  \
# 0   PassengerId                        Identificação do passageiro
# 1      Survived  Verificação se o passageiro sobreviveu(1) ou n...
# 2        Pclass               Tipo da passagem: 1°,2° ou 3° Classe
# 3          Name                                 Nome do passageiro
# 4           Sex                               Gênero do passageiro
# 5           Age                                Idade do passageiro
# 6         SibSp  Quantidade de irmãos ou parceiros abordo no navio
# 7         Parch       Quantidade de pais ou filhos abordo no navio
# 8        Ticket                                 Número da passagem
# 9          Fare                              Tarifa por passageiro
# 10        Cabin                                   Número da cabine
# 11     Embarked  Porto de Embarcação:C = Cherbourg, Q = Queenst...
#
#             Tipo   Subtipo
# 0   quantitativo  discreto
# 1    qualitativo   nominal
# ...
